# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
numpyArray1 = np.linspace(0,10,20)

# %%
numpyArray1
# Out:
# array([ 0.        ,  0.52631579,  1.05263158,  1.57894737,  2.10526316,
#         2.63157895,  3.15789474,  3.68421053,  4.21052632,  4.73684211,
#         5.26315789,  5.78947368,  6.31578947,  6.84210526,  7.36842105,
#         7.89473684,  8.42105263,  8.94736842,  9.47368421, 10.        ])

# %%
numpyArray2 = numpyArray1**2

# %%
(myFig,myAxes)=pyt.subplots()
myAxes.plot(numpyArray1,numpyArray2,color="#3A95A8")
myAxes.plot(numpyArray2,numpyArray1,"r",alpha=0.6)

# %%
(newFig,newAxes)=plt.subplots()
newAxes.plot(numpyArray1,numpyArray1+2,color="blue", linewidth=3.0,linestyle="-.")
newAxes.plot(numpyArray1,numpyArray1+3,color="yellow", linestyle="--")
newAxes.plot(numpyArray1,numpyArray1+4,color="green", linestyle=":",marker = "o",markersize = 5, markerfacecolor="red")

# %% [markdown]
# ## scatter

# %%
plt.scatter(numpyArray1,numpyArray2)

# %% [markdown]
# ## histogram

# %%
newArray = np.random.randint(0,500,80)

# %%
newArray
# Out:
# array([202, 438, 315,   7, 286, 278,  29,  62, 454,  82, 479, 396, 449,
#        492, 175,  91, 390, 117, 180, 126,  39,  98, 304, 454, 433, 462,
#        385, 279, 402,  86, 161, 102, 497,  60, 363, 166, 345, 293, 192,
#        264, 347, 395, 108, 324, 204, 203,  49, 194, 357, 202, 303,  91,
#        246,  76, 175, 217, 455, 281, 131, 233,  48, 333, 445, 163,  37,
#        461, 360, 400, 415, 469,  30,  42, 336, 467, 362, 459, 332, 119,
#        328, 415])

# %%
plt.hist(newArray)
# Out:
# (array([ 8.,  9.,  5., 10.,  5.,  6., 10.,  8.,  7., 12.]),
#  array([  7.,  56., 105., 154., 203., 252., 301., 350., 399., 448., 497.]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## boxplot

# %%
plt.boxplot(newArray*2)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1a23f1cd970>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1a23efb9850>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1a23f1cd4c0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1a23efb91c0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1a23efb95b0>],
#  'means': []}
